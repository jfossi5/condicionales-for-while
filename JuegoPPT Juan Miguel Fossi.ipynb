# %%
import math
import random

# %%
import random

def play():
    user = input(" ¿Qué vas a usar? 'piedra','papel','tijeras' ")
    computer = random.choice (['piedra', 'papel', 'tijeras'])
    
    if user == computer:
        return 'Es un Empate'
    
    if is_win(user, computer):
        return '¡Ganaste!'
    return '¡Perdiste!'

def is_win(player, opponent):
    if (player == 'piedra' and opponent == 'tijeras') or (player == 'tijeras' and opponent == 'papel') \
        or (player == 'papel' and opponent == 'tijeras'):
        return True
    
print(play())
# Out:
# ¡Perdiste!

# %%
for i in range(5):
    print(f"Ronda{i+1}:")
    resultado = play()
    print(resultado)
    print()
# Out:
# Ronda1:
# ¡Ganaste!
#
# Ronda2:
# ¡Ganaste!
#
# Ronda3:
# ¡Perdiste!
#
# Ronda4:
# ¡Perdiste!
#
# Ronda5:
# ¡Perdiste!

# %%
# !"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmmnopqrstuvwxyz
import random
chars = '!"#$%&()*+,-./0123456789?@ABCDEFGHIKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxy'
password= ''
lenghtPW = int(input('Que longitud quieres para tu pw'))

for _ in range(lenghtPW):
    
    password += random.choice(chars)
print(password)
# Out:
# ljtD.

# %%
# !"#$%&()*+,-./0123456789?@ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmmnopqrstuvwxyz



import random
random.seed(1234)
chars = '!"#$%&()*+,-./0123456789?@ABCDEFGHIKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxy'
password= ''

lenghtPW = int(input('Que longitud quieres para tu pw'))

for _ in range(lenghtPW):
    
    password += random.choice(chars)
    
print(password)
# Out:
# f0!-x%,.

# %%
contraseña = "Juanmi123405"
contador = 0 

while True: 
    contraseña_input = input ("Introduzca una contraseña")
    contador +=1
    
    if contador > 2: 
        print("Haz sobrepasado los intentos")
        
    elif contraseña_input == "Juanmi123405": 
        print("Contraseña Correcta")
        break
    
    else: 
        print("Contraseña incorrecta, Introduzca una contraseña correcta")
# Out:
# Contraseña incorrecta, Introduzca una contraseña correcta
# Contraseña incorrecta, Introduzca una contraseña correcta
# Haz sobrepasado los intentos
